# %% [markdown]
# <a href="https://colab.research.google.com/github/247598/Codsoft-Titanic-Survival-Prediction-Logeshwar-U/blob/main/Titanic_Survival_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Important Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Importing CSV File and named as 'tea'**

# %%
tea = pd.read_csv("/tested.csv")

# %% [markdown]
# **printing 'tea'**

# %%
print(tea)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# **For Finding Mean**

# %%
tea.mean()
# Out:
# <ipython-input-125-0276cc039d6f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tea.mean()
# PassengerId    1100.500000
# Survived          0.363636
# Pclass            2.265550
# Age              30.272590
# SibSp             0.447368
# Parch             0.392344
# Fare             35.627188
# dtype: float64

# %% [markdown]
# **For Finding Median**

# %%
tea.median()
# Out:
# <ipython-input-126-4a324c1eb391>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tea.median()
# PassengerId    1100.5000
# Survived          0.0000
# Pclass            3.0000
# Age              27.0000
# SibSp             0.0000
# Parch             0.0000
# Fare             14.4542
# dtype: float64

# %% [markdown]
# **For Making Graph**

# %%
tea.plot()
# Out:
# <Axes: >

# %% [markdown]
# **For Creating "name_column"**

# %%
name_column = tea["Name"]
print(name_column)
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# **For Creating "id_column"**

# %%
id_column = tea["PassengerId"]
print(id_column)
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %% [markdown]
# **For creating id_column's graph**

# %%
id_column.plot()
# Out:
# <Axes: >

# %% [markdown]
# **For Creating "pclass_column"**

# %%
pclass_column = tea["Pclass"]
print(pclass_column)
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %% [markdown]
# **For Creating pclass_column's graph**

# %%
pclass_column.plot()
# Out:
# <Axes: >

# %% [markdown]
# **For Creating "sex_column"**

# %%
sex_column = tea["Sex"]
print(sex_column)
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4      female
#         ...
# 413      male
# 414    female
# 415      male
# 416      male
# 417      male
# Name: Sex, Length: 418, dtype: object

# %% [markdown]
# **"survived_column" creation**

# %%
survived_column = tea["Survived"]
print(survived_column)
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %% [markdown]
# **survived_column's graph creation and description**

# %%
survived_column.plot(kind='line',y='survived')
# Out:
# <Axes: >

# %%
survived_column.describe()
# Out:
#          Survived
# count  418.000000
# mean     0.363636
# std      0.481622
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# **By Using If Statements , We can easily find whether he is survived or not.**

# %%
survived_column = int(input("Enter the id:"))
if(survived_column==0):
  print("Not Survived")
else:
  print("Survived")
# Out:
# Enter the id:414
# Survived
